# %%
# Importing library and analysis tools
import requests 
import pandas as pd 
import scipy.stats as stats
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
# Pulling Population Estimate API data from census.gov
url = "https://api.census.gov/data/2021/pep/population?"
params = {
    "get": "NAME,DENSITY_2021,POP_2021",
    "for": "state:*",
    "key": "b4e8cddedd39b4cba2d10cd09ac941213d4f6680"
}
response = requests.get(url, params=params)

if response.status_code == 200:
    pop_apijson = response.json()
else:
    print("API request failed.")

# Formatting API data into a Data Frame
pop_api = pd.DataFrame(pop_apijson)
pop_api.columns = pop_api.iloc[0]
pop_api = pop_api[1:].reset_index(drop =True)
pop_api.sort_values(by ="NAME", ascending =True, inplace =True)
pop_api.reset_index(drop =True, inplace =True)
pop_api.dropna(inplace =True)
pop_api["POP_2021"] = pop_api["POP_2021"].astype('int64')
pop_api["DENSITY_2021"] = pop_api["DENSITY_2021"].astype('float64')

# %%
pop_api
# Out:
# 0                   NAME  DENSITY_2021  POP_2021 state
# 0                Alabama     99.509913   5039877    01
# 1                 Alaska      1.283093    732673    02
# 2                Arizona     64.022114   7276316    04
# 3               Arkansas     58.194679   3025891    05
# 4             California    251.754362  39237836    06
# 5               Colorado     56.081421   5812069    08
# 6            Connecticut    744.556991   3605597    09
# 7               Delaware    514.938620   1003384    10
# 8   District of Columbia  10961.845722    670050    11
# 9                Florida    405.980418  21781128    12
# 10               Georgia    187.112585  10799566    13
# 11                Hawaii    224.456138   1441553    15
# 12                 Idaho     23.001023   1900923    16
# 13              Illinois    228.258855  12671469    17
# 14               Indiana    189.973578   6805985    18
# 15                  Iowa     57.169008   3193079    19
# 16                Kansas     35.893254   2934582    20
# 17              Kentucky    114.186468   4509394    21
# 18             Louisiana    107.010359   4624047    22
# 19                 Maine     44.488287   1372247    23
# 20              Maryland    634.849038   6165129    24
# 21         Massachusetts    895.369530   6984723    25
# 22              Michigan    177.551936  10050811    26
# 23             Minnesota     71.677007   5707390    27
# 24           Mississippi     62.866946   2949965    28
# 25              Missouri     89.723504   6168187    29
# 26               Montana      7.586865   1104271    30
# 27              Nebraska     25.562964   1963692    31
# 28                Nevada     28.618062   3143991    32
# 29         New Hampshire    155.129503   1388992    33
# 30            New Jersey   1260.029076   9267130    34
# 31            New Mexico     17.441507   2115877    35
# 32              New York    420.935960  19835913    36
# 33        North Carolina    216.999717  10551162    37
# 34          North Dakota     11.231804    774948    38
# 35                  Ohio    288.309817  11780017    39
# 36              Oklahoma     58.117159   3986639    40
# 37                Oregon     44.232678   4246155    41
# 38          Pennsylvania    289.749786  12964056    42
# 40          Rhode Island   1059.698994   1095610    44
# 41        South Carolina    172.653449   5190705    45
# 42          South Dakota     11.810849    895376    46
# 43             Tennessee    169.167902   6975218    47
# 44                 Texas    113.018201  29527941    48
# 45                  Utah     40.520796   3337975    49
# 46               Vermont     70.037812    645570    50
# 47              Virginia    218.890512   8642274    51
# 48            Washington    116.449709   7738692    53
# 49         West Virginia     74.162763   1782959    54
# 50             Wisconsin    108.846155   5895908    55
# 51               Wyoming      5.961589    578803    56

# %%
# Importing the .csv data files.
filepaths = []
dataframes = []

basefilepath = "./data/mod/{csvfilename}mod.csv"
csvfilename = ["car","edu1","gdp","pub","unem"]

for filename in csvfilename:
    filepath = basefilepath.format(csvfilename=filename)
    filepaths.append(filepath)
    df=pd.read_csv(filepath)
    dataframes.append(df)

# %%
dataframes
# Out:
# [                   State  Registered Vehicles  Avg Cars per Household  \
#  0                Alabama              5288209                    1.92
#  1                 Alaska               795274                    1.81
#  2                Arizona              5982559                    1.84
#  3               Arkansas              2902111                    1.84
#  4             California             31247270                    1.92
#  5               Colorado              5412403                    1.96
#  6            Connecticut              2878547                    1.77
#  7               Delaware              1016927                    1.81
#  8   District of Columbia                    0                    0.00
#  9                Florida             17833719                    1.70
#  10               Georgia              8594567                    1.86
#  11                Hawaii              1272361                    1.85
#  12                 Idaho              1954528                    2.13
#  13              Illinois             10691947                    1.67
#  14               Indiana              6223459                    1.87
#  15                  Iowa              3786328                    1.95
#  16                Kansas              2682337                    1.96
#  17              Kentucky              4383222                    1.85
#  18             Louisiana              3802746                    1.68
#  19                 Maine              1130055                    1.80
#  20              Maryland              4203994                    1.80
#  21         Massachusetts              5061260                    1.62
#  22              Michigan              8440064                    1.77
#  23             Minnesota              5425884                    1.89
#  24           Mississippi              2066680                    1.86
#  25              Missouri              5534289                    1.84
#  26               Montana              1900806                    2.07
#  27              Nebraska              1968480                    1.98
#  28                Nevada              2546583                    1.81
#  29         New Hampshire              1363379                    1.90
#  30            New Jersey              6033015                    1.68
#  31            New Mexico              1825421                    1.91
#  32              New York             11389158                    1.25
#  33        North Carolina              8527388                    1.91
#  34          North Dakota               903668                    1.97
#  35                  Ohio             10901279                    1.79
#  36              Oklahoma              3706624                    1.90
#  37                Oregon              3919158                    1.88
#  38          Pennsylvania             10800315                    1.69
#  39          Rhode Island               868942                    1.67
#  40        South Carolina              4516143                    1.87
#  41          South Dakota              1280969                    2.04
#  42             Tennessee              5817887                    1.93
#  43                 Texas             23007145                    1.87
#  44                  Utah              2430276                    2.15
#  45               Vermont               620428                    1.74
#  46              Virginia              7647691                    1.94
#  47            Washington              7377028                    1.93
#  48         West Virginia              1668114                    1.76
#  49             Wisconsin              5666399                    1.83
#  50               Wyoming               843672                    2.14
#
#      % With No Access, 2019  No Access
#  0                   0.0603       6.03
#  1                   0.0993       9.93
#  2                   0.0597       5.97
#  3                   0.0639       6.39
#  4                   0.0707       7.07
#  5                   0.0514       5.14
#  6                   0.0866       8.66
#  7                   0.0567       5.67
#  8                   0.0000       0.00
#  9                   0.0615       6.15
#  10                  0.0644       6.44
#  11                  0.0771       7.71
#  12                  0.0410       4.10
#  13                  0.1106      11.06
#  14                  0.0649       6.49
#  15                  0.0606       6.06
#  16                  0.0534       5.34
#  17                  0.0724       7.24
#  18                  0.0852       8.52
#  19                  0.0636       6.36
#  20                  0.0909       9.09
#  21                  0.1242      12.42
#  22                  0.0752       7.52
#  23                  0.0660       6.60
#  24                  0.0649       6.49
#  25                  0.0693       6.93
#  26                  0.0459       4.59
#  27                  0.0539       5.39
#  28                  0.0707       7.07
#  29                  0.0529       5.29
#  30                  0.1156      11.56
#  31                  0.0584       5.84
#  32                  0.2937      29.37
#  33                  0.0580       5.80
#  34                  0.0534       5.34
#  35                  0.0772       7.72
#  36                  0.0562       5.62
#  37                  0.0775       7.75
#  38                  0.1100      11.00
#  39                  0.0973       9.73
#  40                  0.0595       5.95
#  41                  0.0510       5.10
#  42                  0.0565       5.65
#  43                  0.0539       5.39
#  44                  0.0385       3.85
#  45                  0.0687       6.87
#  46                  0.0614       6.14
#  47                  0.0711       7.11
#  48                  0.0928       9.28
#  49                  0.0671       6.71
#  50                  0.0437       4.37  ,
#                     State  High School Or Higher  Bachelors Or Higher
#  0                Alabama                   86.9                 26.2
#  1                 Alaska                   93.1                 30.0
#  2                Arizona                   87.9                 30.3
#  3               Arkansas                   87.2                 23.8
#  4             California                   83.9                 34.7
#  5               Colorado                   92.1                 41.6
#  6            Connecticut                   90.9                 40.0
#  7               Delaware                   90.6                 32.7
#  8   District of Columbia                   91.9                 59.8
#  9                Florida                   88.5                 30.5
#  10               Georgia                   87.9                 32.2
#  11                Hawaii                   92.5                 33.6
#  12                 Idaho                   91.3                 28.7
#  13              Illinois                   89.7                 35.5
#  14               Indiana                   89.3                 27.2
#  15                  Iowa                   92.5                 29.3
#  16                Kansas                   91.4                 33.9
#  17              Kentucky                   87.2                 25.0
#  18             Louisiana                   85.9                 24.9
#  19                 Maine                   93.2                 32.5
#  20              Maryland                   90.6                 40.9
#  21         Massachusetts                   91.1                 44.5
#  22              Michigan                   91.3                 30.0
#  23             Minnesota                   93.4                 36.8
#  24           Mississippi                   85.3                 22.8
#  25              Missouri                   90.6                 29.9
#  26               Montana                   94.0                 33.1
#  27              Nebraska                   91.6                 32.5
#  28                Nevada                   86.9                 25.5
#  29         New Hampshire                   93.3                 37.6
#  30            New Jersey                   90.3                 40.7
#  31            New Mexico                   86.5                 28.1
#  32              New York                   87.2                 37.5
#  33        North Carolina                   88.5                 32.0
#  34          North Dakota                   93.1                 30.7
#  35                  Ohio                   90.8                 28.9
#  36              Oklahoma                   88.6                 26.1
#  37                Oregon                   91.1                 34.4
#  38          Pennsylvania                   91.0                 32.3
#  39          Rhode Island                   89.2                 35.0
#  40        South Carolina                   88.3                 29.0
#  41          South Dakota                   92.2                 29.3
#  42             Tennessee                   88.2                 28.2
#  43                 Texas                   84.4                 30.7
#  44                  Utah                   93.0                 34.7
#  45               Vermont                   93.5                 39.7
#  46              Virginia                   90.3                 39.5
#  47            Washington                   91.7                 36.7
#  48         West Virginia                   87.6                 21.3
#  49             Wisconsin                   92.6                 30.8
#  50               Wyoming                   93.6                 28.2,
#                     State  GDP Per Capita
#  0                Alabama           50637
#  1                 Alaska           68919
#  2                Arizona           56667
#  3               Arkansas           51787
#  4             California           77339
#  5               Colorado           74167
#  6            Connecticut           84972
#  7               Delaware           61387
#  8   District of Columbia           96728
#  9                Florida           63597
#  10               Georgia           57129
#  11                Hawaii           61175
#  12                 Idaho           54537
#  13              Illinois           68822
#  14               Indiana           57930
#  15                  Iowa           58905
#  16                Kansas           60152
#  17              Kentucky           52109
#  18             Louisiana           54622
#  19                 Maine           59463
#  20              Maryland           70730
#  21         Massachusetts           84945
#  22              Michigan           56813
#  23             Minnesota           68010
#  45                          0.52
#  46                          1.48
#  47                          2.12
#  48                          0.36
#  49                          0.86
#  50                          0.79  ,
#                     State  Unemployment Rate
#  0                Alabama                3.9
#  1                 Alaska                6.6
#  2                Arizona                4.8
#  3               Arkansas                3.7
#  4             California                4.2
#  5               Colorado                3.3
#  6            Connecticut                4.1
#  7               Delaware                3.8
#  8   District of Columbia                5.6
#  9                Florida                3.6
#  10               Georgia                3.9
#  11                Hawaii                2.4
#  12                 Idaho                2.8
#  13              Illinois                4.3
#  14               Indiana                3.4
#  15                  Iowa                2.5
#  16                Kansas                3.4
#  17              Kentucky                4.3
#  18             Louisiana                4.9
#  19                 Maine                3.4
#  20              Maryland                3.9
#  21         Massachusetts                3.3
#  22              Michigan                4.1
#  23             Minnesota                2.9
#  24           Mississippi                4.8
#  25              Missouri                3.2
#  26               Montana                3.7
#  27              Nebraska                2.8
#  28                Nevada                4.6
#  29         New Hampshire                2.5
#  30            New Jersey                4.1
#  31            New Mexico                4.9
#  32              New York                4.1
#  33        North Carolina                3.9
#  34          North Dakota                2.6
#  35                  Ohio                4.6
#  36              Oklahoma                3.4
#  37                Oregon                4.2
#  38          Pennsylvania                4.3
#  39          Rhode Island                4.1
#  40        South Carolina                3.4
#  41          South Dakota                3.0
#  42             Tennessee                3.5
#  43                 Texas                3.9
#  44                  Utah                3.1
#  45               Vermont                2.7
#  46              Virginia                3.0
#  47            Washington                4.5
#  48         West Virginia                5.3
#  49             Wisconsin                3.0
#  50               Wyoming                4.1]

# %%
# Combining all of the Data Frames created from the .csv files and API data.
main = pd.merge(dataframes[0], pop_api, left_on="State", right_on ="NAME")
main = main.merge(dataframes[1], on = "State")
main = main.merge(dataframes[2], on = "State")
main = main.merge(dataframes[3], on = "State")
main = main.merge(dataframes[4], on = "State")

# %%
main
# Out:
#                    State  Registered Vehicles  Avg Cars per Household  \
# 0                Alabama              5288209                    1.92
# 1                 Alaska               795274                    1.81
# 2                Arizona              5982559                    1.84
# 3               Arkansas              2902111                    1.84
# 4             California             31247270                    1.92
# 5               Colorado              5412403                    1.96
# 6            Connecticut              2878547                    1.77
# 7               Delaware              1016927                    1.81
# 8   District of Columbia                    0                    0.00
# 9                Florida             17833719                    1.70
# 10               Georgia              8594567                    1.86
# 11                Hawaii              1272361                    1.85
# 12                 Idaho              1954528                    2.13
# 13              Illinois             10691947                    1.67
# 14               Indiana              6223459                    1.87
# 15                  Iowa              3786328                    1.95
# 16                Kansas              2682337                    1.96
# 17              Kentucky              4383222                    1.85
# 18             Louisiana              3802746                    1.68
# 19                 Maine              1130055                    1.80
# 20              Maryland              4203994                    1.80
# 21         Massachusetts              5061260                    1.62
# 22              Michigan              8440064                    1.77
# 23             Minnesota              5425884                    1.89
# 24           Mississippi              2066680                    1.86
# 25              Missouri              5534289                    1.84
# 26               Montana              1900806                    2.07
# 27              Nebraska              1968480                    1.98
# 28                Nevada              2546583                    1.81
# 29         New Hampshire              1363379                    1.90
# 30            New Jersey              6033015                    1.68
# 31            New Mexico              1825421                    1.91
# 32              New York             11389158                    1.25
# 33        North Carolina              8527388                    1.91
# 50                  0.0437       4.37               Wyoming      5.961589
#
#     POP_2021 state  High School Or Higher  Bachelors Or Higher  \
# 0    5039877    01                   86.9                 26.2
# 1     732673    02                   93.1                 30.0
# 2    7276316    04                   87.9                 30.3
# 3    3025891    05                   87.2                 23.8
# 4   39237836    06                   83.9                 34.7
# 5    5812069    08                   92.1                 41.6
# 6    3605597    09                   90.9                 40.0
# 7    1003384    10                   90.6                 32.7
# 8     670050    11                   91.9                 59.8
# 9   21781128    12                   88.5                 30.5
# 10  10799566    13                   87.9                 32.2
# 11   1441553    15                   92.5                 33.6
# 12   1900923    16                   91.3                 28.7
# 13  12671469    17                   89.7                 35.5
# 14   6805985    18                   89.3                 27.2
# 15   3193079    19                   92.5                 29.3
# 16   2934582    20                   91.4                 33.9
# 17   4509394    21                   87.2                 25.0
# 18   4624047    22                   85.9                 24.9
# 19   1372247    23                   93.2                 32.5
# 20   6165129    24                   90.6                 40.9
# 21   6984723    25                   91.1                 44.5
# 22  10050811    26                   91.3                 30.0
# 23   5707390    27                   93.4                 36.8
# 24   2949965    28                   85.3                 22.8
# 25   6168187    29                   90.6                 29.9
# 26   1104271    30                   94.0                 33.1
# 27   1963692    31                   91.6                 32.5
# 28   3143991    32                   86.9                 25.5
# 29   1388992    33                   93.3                 37.6
# 30   9267130    34                   90.3                 40.7
# 31   2115877    35                   86.5                 28.1
# 32  19835913    36                   87.2                 37.5
# 33  10551162    37                   88.5                 32.0
# 34    774948    38                   93.1                 30.7
# 35  11780017    39                   90.8                 28.9
# 36   3986639    40                   88.6                 26.1
# 37   4246155    41                   91.1                 34.4
# 38  12964056    42                   91.0                 32.3
# 39   1095610    44                   89.2                 35.0
# 40   5190705    45                   88.3                 29.0
# 41    895376    46                   92.2                 29.3
# 42   6975218    47                   88.2                 28.2
# 43  29527941    48                   84.4                 30.7
# 44   3337975    49                   93.0                 34.7
# 45    645570    50                   93.5                 39.7
# 46   8642274    51                   90.3                 39.5
# 47   7738692    53                   91.7                 36.7
# 48   1782959    54                   87.6                 21.3
# 49   5895908    55                   92.6                 30.8
# 50    578803    56                   93.6                 28.2
#
#     GDP Per Capita  Commute mode share (decimal)  \
# 0            50637                      0.002299
# 1            68919                      0.008672
# 2            56667                      0.009383
# 3            51787                      0.001892
# 4            77339                      0.020680
# 5            74167                      0.013222
# 6            84972                      0.024589
# 7            61387                      0.016261
# 8            96728                      0.116184
# 9            63597                      0.009749
# 10           57129                      0.007092
# 11           61175                      0.032950
# 12           54537                      0.004792
# 13           68822                      0.038303
# 14           57930                      0.005582
# 15           58905                      0.004865
# 16           60152                      0.002660
# 17           52109                      0.005349
# 18           54622                      0.007489
# 19           59463                      0.002577
# 20           70730                      0.029869
# 21           84945                      0.045050
# 22           56813                      0.008414
# 23           68010                      0.013972
# 24           46248                      0.002346
# 25           56551                      0.007674
# 26           57719                      0.004093
# 27           63321                      0.004216
# 28           61282                      0.019849
# 29           74663                      0.003451
# 30           78700                      0.058705
# 31           51500                      0.003659
# 32           78089                      0.172589
# 33           57416                      0.005136
# 34           66184                      0.002664
# 35           57880                      0.008111
# 36           54998                      0.001775
# 37           62767                      0.016520
# 38           65167                      0.027904
# 39           65377                      0.011537
# 40           53320                      0.003175
# 41           65806                      0.004190
# 42           58279                      0.003561
# 43           61985                      0.007537
# 44           57925                      0.013313
# 45           63206                      0.005197
# 46           68211                      0.014760
# 47           75698                      0.021236
# 48           49169                      0.003574
# 49           61210                      0.008592
# 50           71342                      0.007940
#
#     Commute mode share (percent)  Unemployment Rate
# 0                           0.23                3.9
# 1                           0.87                6.6
# 2                           0.94                4.8
# 3                           0.19                3.7
# 4                           2.07                4.2
# 5                           1.32                3.3
# 6                           2.46                4.1
# 7                           1.63                3.8
# 8                          11.62                5.6
# 9                           0.97                3.6
# 10                          0.71                3.9
# 11                          3.29                2.4
# 12                          0.48                2.8
# 13                          3.83                4.3
# 14                          0.56                3.4
# 15                          0.49                2.5
# 16                          0.27                3.4
# 17                          0.53                4.3
# 18                          0.75                4.9
# 19                          0.26                3.4
# 20                          2.99                3.9
# 21                          4.50                3.3
# 22                          0.84                4.1
# 23                          1.40                2.9
# 24                          0.23                4.8
# 25                          0.77                3.2
# 26                          0.41                3.7
# 27                          0.42                2.8
# 28                          1.98                4.6
# 29                          0.35                2.5
# 30                          5.87                4.1
# 31                          0.37                4.9
# 32                         17.26                4.1
# 33                          0.51                3.9
# 34                          0.27                2.6
# 35                          0.81                4.6
# 36                          0.18                3.4
# 37                          1.65                4.2
# 38                          2.79                4.3
# 39                          1.15                4.1
# 40                          0.32                3.4
# 41                          0.42                3.0
# 42                          0.36                3.5
# 43                          0.75                3.9
# 44                          1.33                3.1
# 45                          0.52                2.7
# 46                          1.48                3.0
# 47                          2.12                4.5
# 48                          0.36                5.3
# 49                          0.86                3.0
# 50                          0.79                4.1

# %%
# Cleaning, Renaming, and Reindexing the data column names to be easily read
main = main.drop([
                                    "NAME",
                                    "state",
                                    "% With No Access, 2019",
                                    "Commute mode share (decimal)"
                                    ], axis=1)
main = main.rename(columns={
                                    "Avg Cars per Household":"Cars per Houshold (AVG)",
                                    "No Access":"No Access to Cars (%)",
                                    "High School Or Higher": "High School or Higher (%)",
                                    "Bachelors Or Higher": "Bachelors or Higher (%)",
                                    "GDP Per Capita": "GDP per Capita ($)",
                                    "Commute mode share (percent)": "Uses Public Transportation (%)",
                                    "Unemployment Rate": "Unemployment Rate (%)",
                                    "DENSITY_2021":"Density (per square mile)",
                                    "POP_2021":"Population"
                                    })
main = main.reindex(columns =[
                                    "Uses Public Transportation (%)", 
                                    "State", 
                                    "GDP per Capita ($)",
                                    "Density (per square mile)",
                                    "Population",
                                    "Registered Vehicles",
                                    "Cars per Houshold (AVG)", 
                                    "No Access to Cars (%)",
                                    "Unemployment Rate (%)",
                                    "High School or Higher (%)", 
                                    "Bachelors or Higher (%)"
                                    ])

# %%
main
# Out:
#     Uses Public Transportation (%)                 State  GDP per Capita ($)  \
# 0                             0.23               Alabama               50637
# 1                             0.87                Alaska               68919
# 2                             0.94               Arizona               56667
# 3                             0.19              Arkansas               51787
# 4                             2.07            California               77339
# 5                             1.32              Colorado               74167
# 6                             2.46           Connecticut               84972
# 7                             1.63              Delaware               61387
# 44                  40.520796     3337975              2430276
# 45                  70.037812      645570               620428
# 46                 218.890512     8642274              7647691
# 47                 116.449709     7738692              7377028
# 48                  74.162763     1782959              1668114
# 49                 108.846155     5895908              5666399
# 50                   5.961589      578803               843672
#
#     Cars per Houshold (AVG)  No Access to Cars (%)  Unemployment Rate (%)  \
# 0                      1.92                   6.03                    3.9
# 1                      1.81                   9.93                    6.6
# 2                      1.84                   5.97                    4.8
# 3                      1.84                   6.39                    3.7
# 4                      1.92                   7.07                    4.2
# 5                      1.96                   5.14                    3.3
# 6                      1.77                   8.66                    4.1
# 7                      1.81                   5.67                    3.8
# 8                      0.00                   0.00                    5.6
# 9                      1.70                   6.15                    3.6
# 10                     1.86                   6.44                    3.9
# 11                     1.85                   7.71                    2.4
# 12                     2.13                   4.10                    2.8
# 13                     1.67                  11.06                    4.3
# 14                     1.87                   6.49                    3.4
# 15                     1.95                   6.06                    2.5
# 16                     1.96                   5.34                    3.4
# 17                     1.85                   7.24                    4.3
# 18                     1.68                   8.52                    4.9
# 19                     1.80                   6.36                    3.4
# 20                     1.80                   9.09                    3.9
# 21                     1.62                  12.42                    3.3
# 22                     1.77                   7.52                    4.1
# 23                     1.89                   6.60                    2.9
# 24                     1.86                   6.49                    4.8
# 25                     1.84                   6.93                    3.2
# 26                     2.07                   4.59                    3.7
# 27                     1.98                   5.39                    2.8
# 28                     1.81                   7.07                    4.6
# 29                     1.90                   5.29                    2.5
# 30                     1.68                  11.56                    4.1
# 31                     1.91                   5.84                    4.9
# 32                     1.25                  29.37                    4.1
# 33                     1.91                   5.80                    3.9
# 34                     1.97                   5.34                    2.6
# 35                     1.79                   7.72                    4.6
# 36                     1.90                   5.62                    3.4
# 37                     1.88                   7.75                    4.2
# 38                     1.69                  11.00                    4.3
# 39                     1.67                   9.73                    4.1
# 40                     1.87                   5.95                    3.4
# 41                     2.04                   5.10                    3.0
# 42                     1.93                   5.65                    3.5
# 43                     1.87                   5.39                    3.9
# 44                     2.15                   3.85                    3.1
# 45                     1.74                   6.87                    2.7
# 46                     1.94                   6.14                    3.0
# 47                     1.93                   7.11                    4.5
# 48                     1.76                   9.28                    5.3
# 49                     1.83                   6.71                    3.0
# 50                     2.14                   4.37                    4.1
#
#     High School or Higher (%)  Bachelors or Higher (%)
# 0                        86.9                     26.2
# 1                        93.1                     30.0
# 2                        87.9                     30.3
# 3                        87.2                     23.8
# 4                        83.9                     34.7
# 5                        92.1                     41.6
# 6                        90.9                     40.0
# 7                        90.6                     32.7
# 8                        91.9                     59.8
# 9                        88.5                     30.5
# 10                       87.9                     32.2
# 11                       92.5                     33.6
# 12                       91.3                     28.7
# 13                       89.7                     35.5
# 14                       89.3                     27.2
# 15                       92.5                     29.3
# 16                       91.4                     33.9
# 17                       87.2                     25.0
# 18                       85.9                     24.9
# 19                       93.2                     32.5
# 20                       90.6                     40.9
# 21                       91.1                     44.5
# 22                       91.3                     30.0
# 23                       93.4                     36.8
# 24                       85.3                     22.8
# 25                       90.6                     29.9
# 26                       94.0                     33.1
# 27                       91.6                     32.5
# 28                       86.9                     25.5
# 29                       93.3                     37.6
# 30                       90.3                     40.7
# 31                       86.5                     28.1
# 32                       87.2                     37.5
# 33                       88.5                     32.0
# 34                       93.1                     30.7
# 35                       90.8                     28.9
# 36                       88.6                     26.1
# 37                       91.1                     34.4
# 38                       91.0                     32.3
# 39                       89.2                     35.0
# 40                       88.3                     29.0
# 41                       92.2                     29.3
# 42                       88.2                     28.2
# 43                       84.4                     30.7
# 44                       93.0                     34.7
# 45                       93.5                     39.7
# 46                       90.3                     39.5
# 47                       91.7                     36.7
# 48                       87.6                     21.3
# 49                       92.6                     30.8
# 50                       93.6                     28.2

# %%
mains=main.sort_values(by="Uses Public Transportation (%)", ascending = True)
mains
# Out:
#     Uses Public Transportation (%)                 State  GDP per Capita ($)  \
# 36                            0.18              Oklahoma               54998
# 3                             0.19              Arkansas               51787
# 0                             0.23               Alabama               50637
# 24                            0.23           Mississippi               46248
# 19                            0.26                 Maine               59463
# 34                            0.27          North Dakota               66184
# 16                            0.27                Kansas               60152
# 40                            0.32        South Carolina               53320
# 29                            0.35         New Hampshire               74663
# 42                            0.36             Tennessee               58279
# 48                            0.36         West Virginia               49169
# 31                            0.37            New Mexico               51500
# 26                            0.41               Montana               57719
# 41                            0.42          South Dakota               65806
# 27                            0.42              Nebraska               63321
# 12                            0.48                 Idaho               54537
# 15                            0.49                  Iowa               58905
# 33                            0.51        North Carolina               57416
# 45                            0.52               Vermont               63206
# 17                            0.53              Kentucky               52109
# 14                            0.56               Indiana               57930
# 10                            0.71               Georgia               57129
# 18                            0.75             Louisiana               54622
# 43                            0.75                 Texas               61985
# 25                            0.77              Missouri               56551
# 50                            0.79               Wyoming               71342
# 35                            0.81                  Ohio               57880
# 22                            0.84              Michigan               56813
# 49                            0.86             Wisconsin               61210
# 1                             0.87                Alaska               68919
# 2                             0.94               Arizona               56667
# 9                             0.97               Florida               63597
# 39                            1.15          Rhode Island               65377
# 5                             1.32              Colorado               74167
# 44                            1.33                  Utah               57925
# 23                            1.40             Minnesota               68010
# 46                            1.48              Virginia               68211
# 7                             1.63              Delaware               61387
# 37                            1.65                Oregon               62767
# 28                            1.98                Nevada               61282
# 4                             2.07            California               77339
# 47                            2.12            Washington               75698
# 6                             2.46           Connecticut               84972
# 38                            2.79          Pennsylvania               65167
# 20                            2.99              Maryland               70730
# 11                            3.29                Hawaii               61175
# 13                            3.83              Illinois               68822
# 21                            4.50         Massachusetts               84945
# 30                            5.87            New Jersey               78700
# 8                            11.62  District of Columbia               96728
# 32                           17.26              New York               78089
#
#     Density (per square mile)  Population  Registered Vehicles  \
# 36                  58.117159     3986639              3706624
# 3                   58.194679     3025891              2902111
# 0                   99.509913     5039877              5288209
# 24                  62.866946     2949965              2066680
# 19                  44.488287     1372247              1130055
# 34                  11.231804      774948               903668
# 16                  35.893254     2934582              2682337
# 40                 172.653449     5190705              4516143
# 29                 155.129503     1388992              1363379
# 42                 169.167902     6975218              5817887
# 48                  74.162763     1782959              1668114
# 31                  17.441507     2115877              1825421
# 26                   7.586865     1104271              1900806
# 41                  11.810849      895376              1280969
# 27                  25.562964     1963692              1968480
# 21                     1.62                  12.42                    3.3
# 30                     1.68                  11.56                    4.1
# 8                      0.00                   0.00                    5.6
# 32                     1.25                  29.37                    4.1
#
#     High School or Higher (%)  Bachelors or Higher (%)
# 36                       88.6                     26.1
# 3                        87.2                     23.8
# 0                        86.9                     26.2
# 24                       85.3                     22.8
# 19                       93.2                     32.5
# 34                       93.1                     30.7
# 16                       91.4                     33.9
# 40                       88.3                     29.0
# 29                       93.3                     37.6
# 42                       88.2                     28.2
# 48                       87.6                     21.3
# 31                       86.5                     28.1
# 26                       94.0                     33.1
# 41                       92.2                     29.3
# 27                       91.6                     32.5
# 12                       91.3                     28.7
# 15                       92.5                     29.3
# 33                       88.5                     32.0
# 45                       93.5                     39.7
# 17                       87.2                     25.0
# 14                       89.3                     27.2
# 10                       87.9                     32.2
# 18                       85.9                     24.9
# 43                       84.4                     30.7
# 25                       90.6                     29.9
# 50                       93.6                     28.2
# 35                       90.8                     28.9
# 22                       91.3                     30.0
# 49                       92.6                     30.8
# 1                        93.1                     30.0
# 2                        87.9                     30.3
# 9                        88.5                     30.5
# 39                       89.2                     35.0
# 5                        92.1                     41.6
# 44                       93.0                     34.7
# 23                       93.4                     36.8
# 46                       90.3                     39.5
# 7                        90.6                     32.7
# 37                       91.1                     34.4
# 28                       86.9                     25.5
# 4                        83.9                     34.7
# 47                       91.7                     36.7
# 6                        90.9                     40.0
# 38                       91.0                     32.3
# 20                       90.6                     40.9
# 11                       92.5                     33.6
# 13                       89.7                     35.5
# 21                       91.1                     44.5
# 30                       90.3                     40.7
# 8                        91.9                     59.8
# 32                       87.2                     37.5

# %%
# Statistical Analysis
mainstats = main.corr(numeric_only=True)['Uses Public Transportation (%)'].to_frame()

# Extra credit quick visual
bins = [-1, -0.5, 0, 0.5, 1]
labels = ['- - -', '-', '+', '+ + +']
mainstats['Correlation Category'] = pd.cut(mainstats['Uses Public Transportation (%)'], bins=bins, labels=labels)
mainstats.rename(columns={'Uses Public Transportation (%)': 'Correlation Value','Correlation Category':'Correlation Strength'}, inplace=True)
mainstats['Correlation Value'] = mainstats['Correlation Value'].round(4)

# %%
mainstats
# Out:
#                                 Correlation Value Correlation Strength
# Uses Public Transportation (%)             1.0000                + + +
# GDP per Capita ($)                         0.6235                + + +
# Density (per square mile)                  0.5441                + + +
# Population                                 0.2290                    +
# Registered Vehicles                        0.1199                    +
# Cars per Houshold (AVG)                   -0.7214                - - -
# No Access to Cars (%)                      0.6510                + + +
# Unemployment Rate (%)                      0.2166                    +
# High School or Higher (%)                 -0.0368                    -
# Bachelors or Higher (%)                    0.5830                + + +

# %%
plt.style.use('dark_background')
corr = main.corr(numeric_only=True)
mask = np.triu(np.ones_like(corr, dtype=bool))

f, ax = plt.subplots(figsize=(11, 9))

cmap = sns.diverging_palette(230, 20, as_cmap=True)

sns.heatmap(corr, mask=mask, cmap=cmap, vmax=.3, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})

plt.title('Correlation Matrix of Variables')
plt.show()

# %%
x = main['Uses Public Transportation (%)']
y_gdp = main['GDP per Capita ($)']
y_density = main['Density (per square mile)']
y_population = main['Population']
y_reg_vehicles = main['Registered Vehicles']
y_cars_per_household = main['Cars per Houshold (AVG)']
y_no_access_cars = main['No Access to Cars (%)']
y_unemployment_rate = main['Unemployment Rate (%)']
y_high_school_or_higher = main['High School or Higher (%)']
y_bachelors_or_higher = main['Bachelors or Higher (%)']
plt.figure(figsize=(15, 20))

def scatter_with_trend(x, y, ylabel, title, trend_color='magenta', trend_label=' '):
    plt.scatter(x, y)
    plt.tick_params(axis='both', which='both', bottom=True, left=True, labelbottom=True, labelleft=True)
    plt.title(title)
    slope, intercept = np.polyfit(x, y, 1)
    plt.plot(x, slope * x + intercept, color=trend_color, label=trend_label)
    plt.legend()

plt.subplot(4, 2, 1)
scatter_with_trend(x, y_gdp, ' ','GDP per Capita ($)',trend_color='cyan')
plt.subplot(4, 2, 2)
scatter_with_trend(x, y_density, ' ', 'Density (per square mile)',trend_color='cyan')
plt.subplot(4, 2, 3)
scatter_with_trend(x, y_population, ' ','Population',)
plt.subplot(4, 2, 4)
scatter_with_trend(x, y_reg_vehicles, ' ', 'Registered Vehicles')
plt.subplot(4, 2, 5)
scatter_with_trend(x, y_cars_per_household, ' ','Cars per Houshold (AVG)',trend_color='cyan')
plt.subplot(4, 2, 6)
scatter_with_trend(x, y_no_access_cars, ' ','No Access to Cars (%)',trend_color='cyan')
plt.subplot(4, 2, 7)
scatter_with_trend(x, y_unemployment_rate, ' ','Unemployment Rate (%)')
plt.subplot(4, 2, 8)
scatter_with_trend(x, y_high_school_or_higher, ' ','Education',trend_label='High School')
scatter_with_trend(x, y_bachelors_or_higher, ' ','Education',trend_color='cyan',trend_label='Bachelors')

plt.show()

# %%
plt.figure(figsize=(25, 10))

plt.scatter(x=mains['State'], 
            y=mains['GDP per Capita ($)'], 
            s=mains['Density (per square mile)'] * 1.1,
            c=mains['Bachelors or Higher (%)'],
            cmap='viridis',
            vmin=0, vmax=60)

plt.xticks(rotation=90) 
plt.title('Public Transportation Usage by State vs GDP (2021)\n(Bubble Size Represents Population Density)\n(Color Represents Percentage of People with Bachelors or Higher)')

cbar = plt.colorbar()
cbar.set_label("Percentage of People with Bachelor's or Higher (%)")
cbar.set_ticks([0, 15, 30, 45, 60])

plt.tight_layout()

plt.show()

# %%
x = main['Density (per square mile)']
y = main['Cars per Houshold (AVG)']

plt.figure(figsize=(8, 6))
plt.scatter(x, y, c='cyan', alpha=0.7)

plt.xlabel('Density (per square mile)')
plt.ylabel('Cars per Household (AVG)')
plt.title('Scatter Plot: Density vs. Cars per Household')

plt.xlim(0, 1250)

plt.show()

# %%
x = main['Bachelors or Higher (%)']
y = main['Density (per square mile)']

z_scores_x = np.abs(stats.zscore(x))
z_scores_y = np.abs(stats.zscore(y))

threshold = 2

x_without_outliers = x[z_scores_x <= threshold]
y_without_outliers = y[z_scores_y <= threshold]

plt.figure(figsize=(10, 6))
plt.scatter(x_without_outliers, y_without_outliers, c='cyan', marker='o', alpha=0.7)

coefficients = np.polyfit(x_without_outliers, y_without_outliers, 1)
trendline = np.polyval(coefficients, x_without_outliers)

plt.plot(x_without_outliers, trendline, color='red', label='Trend Line')

plt.xlabel('Bachelors or Higher (%)')
plt.ylabel('Density (per square mile)')

plt.title('Scatter Plot: Bachelors vs. Density with Trend Line (Outliers Removed)')

plt.legend()
plt.show()
